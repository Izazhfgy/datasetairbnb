# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("latihan_2_perjalanan.csv")
# Melihat tipe data setiap kolom
df.dtypes
# Out:
# tanggal_waktu       object
# jarak              float64
# durasi               int64
# harga                int64
# driver_rating      float64
# customer_rating    float64
# dtype: object

# %%
# Mengubah kolom tanggal_film menjadi datetime
df['tanggal_waktu'] = pd.to_datetime(df['tanggal_waktu'], errors='coerce')

# %%
# Menampilkan jumlah missing values per kolom
df.isnull().sum()
# Out:
# tanggal_waktu      0
# jarak              0
# durasi             0
# harga              0
# driver_rating      0
# customer_rating    0
# dtype: int64

# %%
df.head(20)
# Out:
#          tanggal_waktu  jarak  durasi   harga  driver_rating  customer_rating
# 0  2024-06-25 19:14:26  19.40      61  101680            1.4              4.1
# 1  2024-06-18 12:58:56   5.61      33   14000            4.6              3.2
# 2  2024-06-21 09:00:27  29.34      82  111042            3.0              2.7
# 3  2024-06-02 10:28:43   2.76      96  103610            4.3              4.6
# 4  2024-06-11 20:01:33  23.81      73  113691            2.3              1.4
# 5  2024-06-14 02:19:25  27.59      51   48304            4.6              3.0
# 6  2024-06-03 01:31:14  15.04     117   79449            2.6              1.0
# 7  2024-06-23 08:36:00  29.95      98   92986            1.0              2.9
# 8  2024-06-02 12:29:33   2.49     114  118940            4.6              1.2
# 9  2024-06-02 08:01:34   2.83      66   48494            1.4              1.5
# 10 2024-06-24 09:12:00  41.31      73   13373            2.3              1.5
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df['tanggal'] = pd.to_datetime(df['tanggal_waktu']).dt.date
df['jam'] = pd.to_datetime(df['tanggal_waktu']).dt.hour
df.groupby('tanggal').size().plot(kind='line')  # volume order harian
sns.barplot(x='jam', y='harga', data=df)  # rata-rata harga per jam
# Out:
# <Axes: xlabel='jam', ylabel='harga'>

# %%
sns.scatterplot(x='jarak', y='durasi', data=df)
sns.scatterplot(x='harga', y='durasi', data=df)
# Out:
# <Axes: xlabel='jarak', ylabel='durasi'>

# %%
sns.scatterplot(x='jarak', y='durasi', data=df)
# Out:
# <Axes: xlabel='jarak', ylabel='durasi'>

# %%
sns.scatterplot(x='harga', y='durasi', data=df)
# Out:
# <Axes: xlabel='harga', ylabel='durasi'>

# %%
sns.boxplot(x='jam', y='customer_rating', data=df)
# Out:
# <Axes: xlabel='jam', ylabel='customer_rating'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
